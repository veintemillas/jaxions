# %%
import numpy as np
import matplotlib.pyplot as plt
from pyaxions import jaxions as pa
import importlib
plt.rcParams["figure.figsize"] = (20,10)

# %%
f  = pa.findmfiles('out')
logi = pa.gml(f ,'logi') 
ct   = pa.gml(f ,'ct') 
st  = pa.stringo(f)
f[-1]
# Out:
# 'out/m/axion.m.00013'

# %%
ea = pa.energoA(f) 
es = pa.energoS(f) 
plt.plot(ct,ea[:,1],'C0',linewidth=2)
plt.plot(ct,ea[:,2],'C1',linewidth=2)
plt.plot(ct,es[:,1],'C0:',linewidth=2)
plt.plot(ct,es[:,2],'C1:',linewidth=2)
plt.plot(ct,es[:,3],'C2:',linewidth=2)

# %%
au=pa.gm(f[-1],'maprho')
plt.imshow(au)

# %%
plt.plot(au[:,0])
